# %%
import matplotlib.pyplot as plt
ax = plt.gca()
ax.plot([1,2],[21,10])
ax.plot([2,0],[2,5])
ax.plot([2,3],[10,1])
ax.scatter([1,2,3],[2,4,5])
plt.ylimit(0,100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ec2a9f1d4db4> in <module>()
#       5 ax.plot([2,3],[10,1])
#       6 ax.scatter([1,2,3],[2,4,5])
# ----> 7 plt.ylimit(0,100)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylimit'
